# %%
import sys
from pathlib import Path

import pandas as pd

sys.path.insert(0, str(Path.cwd().parent / "src"))

from sportsagent.datasource import get_datasource
from sportsagent.utils.visualization_helpers import encode_team_logo

# %%
datasource = get_datasource()
TEAM_COLORS = datasource.TEAM_COLORS
TEAM_LOGO_PATHS = datasource.TEAM_LOGO_PATHS

# %%
REPORT_DIR = Path.cwd().parent / "data" / "outputs" / "20260104_094009_teamstats-ALL_passingyards-passinginterceptions_2025"

csv_files = list(REPORT_DIR.glob("*.csv"))
df = pd.read_csv(csv_files[0])
# df.head()

# %% [markdown]
# # PASTE BELOW

# %%
def generate_plot(df):
    fig = None
    return fig

# %%
generate_plot(df)
